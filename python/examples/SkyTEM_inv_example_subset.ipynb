# %%
import numpy as np
import pandas as pd
import os
# %matplotlib notebook
import matplotlib.pyplot as plt
import sys
import copy

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %load_ext autoreload
# %autoreload 2

from gaaem_utils import *

# %%
data_dir='/Users/mp/Python/ga-aem-emrld/examples/bhmar-skytem/galeisbstdem/output'
data_file="inversion.output.0000.asc"
data_fullfile=os.path.join(data_dir, data_file)

# %%
model=read_GAAEM_data(data_fullfile)

# %%
model["flightlines"].shape
# Out:
# (334, 31)

# %%
model["flightlines"].index
# Out:
# RangeIndex(start=0, stop=334, step=1)

# %%
fig, ax = plt.subplots()
ax.plot(model["flightlines"].easting, model["flightlines"].northing, ".-", ms=3)
ax.plot(model["flightlines"].easting.iloc[0], model["flightlines"].northing.iloc[0], "ko")

ax.set_aspect("equal")
ax.grid()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
model["layer_data"].keys()
# Out:
# dict_keys(['conductivity', 'thickness', 'observed_EMSystem_1_ZS', 'observed_EMSystem_2_ZS', 'noise_EMSystem_1_ZS', 'noise_EMSystem_2_ZS', 'predicted_EMSystem_1_ZS', 'predicted_EMSystem_2_ZS'])

# %%
calc_lineOffset(model)

# %%
model["flightlines"].columns
# Out:
# Index(['uniqueid', 'survey', 'date', 'line', 'fiducial', 'easting', 'northing',
#        'elevation', 'input_tx_height', 'input_tx_roll', 'input_tx_pitch',
#        'input_tx_yaw', 'input_txrx_dx', 'input_txrx_dy', 'input_txrx_dz',
#        'input_rx_roll', 'input_rx_pitch', 'input_rx_yaw', 'nlayers', 'AlphaC',
#        'AlphaT', 'AlphaG', 'AlphaS', 'PhiD', 'PhiM', 'PhiC', 'PhiT', 'PhiG',
#        'PhiS', 'Lambda', 'Iterations', 'lineoffset'],
#       dtype='object')

# %%
make_XYZ_model(model)

# %%
fig, ax = GALEI_invQCplot(model, keyx="easting")
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">
# /Users/mp/Python/ga-aem_utils/venvGAAEM/lib/python3.8/site-packages/gaaem_utils/__init__.py:69: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   pm=ax.pcolormesh(local_x, depth, image_data, cmap=cmap, shading='auto', vmin=clim[0], vmax=clim[1] )

# %%
ax[3].get_xlim()
# Out:
# (603036.5, 609741.2)
